# %% [markdown]
# # AI Occupational Exposure (AIOE) 분석 프로젝트
#
# **"내 직업이 AI에 얼마나 노출될까?"**
#
# ---
#
# ## 환영합니다! 👋
#
# 이 프로젝트에서는 **894개 직업**이 **AI 기술(특히 언어 모델)에 얼마나 노출되는지**를 데이터로 분석합니다.
#
# ChatGPT, Claude, Gemini 같은 AI가 등장하면서 많은 사람들이 궁금해합니다:
# - 🤔 "내 직업이 AI에 의해 대체될까?"
# - 🤔 "AI가 내 업무를 얼마나 도와줄 수 있을까?"
# - 🤔 "어떤 직업이 AI의 영향을 많이 받을까?"
#
# **이 프로젝트는 데이터 기반으로 이런 질문에 답합니다.**

# %% [markdown]
# ---
#
# ## AIOE란 무엇인가요?
#
# AIOE (AI Occupational Exposure)는 특정 직업이 AI 기술에 얼마나 노출되어 있는지를 측정하는 지표입니다.
#
# ### 핵심 아이디어
#
# 모든 직업은 다양한 능력(Abilities)을 필요로 합니다:
# - 📖 읽고 이해하기 (Written Comprehension)
# - 🗣️ 말로 표현하기 (Oral Expression)
# - 🧮 수학적 추론 (Mathematical Reasoning)
# - 💪 신체적 힘 (Static Strength)
# - ... 총 **52개 능력**
#
# **각 능력마다 AI가 잘하는 정도가 다릅니다:**
# - ✅ AI가 **잘하는 능력**: 텍스트 이해, 음성 인식, 번역, 계산
# - ❌ AI가 **못하는 능력**: 신체적 힘, 손재주, 균형감각
#
# **AIOE는 이렇게 계산됩니다:**
#
# ```
# AIOE = (AI가 도와줄 수 있는 능력들의 가중치 합) / (전체 능력의 가중치 합)
# ```
#
# **결과:**
# - **높은 AIOE** → AI가 해당 직업의 많은 능력을 대체하거나 보완할 수 있음
# - **낮은 AIOE** → AI가 해당 직업의 능력을 대체하기 어려움

# %% [markdown]
# ---
#
# ## 이 연구는 어디서 나왔나요?
#
# ### 논문 정보
#
# **제목:** *Occupational, industry, and geographic exposure to artificial intelligence: A novel dataset and its potential uses*
#
# **저자:**
# - Edward Felten (Princeton University)
# - Manav Raj (New York University)
# - Robert Seamans (New York University)
#
# **출판:** 2021년, *Strategic Management Journal*
#
# **핵심 질문:**
# > "AI 기술이 어떤 직업에 영향을 미칠까? 직업, 산업, 지역별로 AI 노출도를 어떻게 측정할 수 있을까?"
#
# ### 연구 방법
#
# 1. **O*NET 데이터 활용**
#    - 미국 노동부가 관리하는 세계 최대 직업 정보 DB
#    - 800여 개 직업 × 52개 능력 데이터
#    - 각 능력의 중요도(Importance)와 수준(Level)
#
# 2. **MTurk 크라우드소싱**
#    - Amazon Mechanical Turk를 통해 AI 전문가들이 평가
#    - "각 AI 응용 프로그램이 52개 능력을 얼마나 잘 수행하는가?" 평가
#    - 10개 AI 응용 프로그램 × 52개 능력 → Beta 값 (0-1)
#
# 3. **AIOE 지표 개발**
#    - 두 데이터를 결합하여 각 직업의 AI 노출도 계산
#    - 능력 기반 접근: 직업이 필요로 하는 능력 × AI가 잘하는 능력
#    - 재현 가능하고 투명한 계산 방법론
#
# ### 주요 발견
#
# - 📊 **높은 임금 직업**이 AI 노출도가 높은 경향
# - 💼 **화이트칼라 직업**이 블루칼라보다 AI 영향을 많이 받음
# - 🏙️ **도시 지역**이 시골보다 AI 노출도 높음
# - 📈 **산업별로** AI 노출도에 큰 차이 존재
#
# ### 후속 연구
#
# **GPTs are GPTs (Eloundou et al., 2023)**
# - OpenAI 연구진이 Felten의 방법론을 확장
# - 대형 언어 모델(GPT)의 영향 분석
# - "19%의 업무가 절반 이상 AI의 영향을 받는다"는 발견

# %% [markdown]
# ---
#
# ## 이 프로젝트의 목표
#
# ### 학습 목표
#
# 이 프로젝트를 통해 다음을 배웁니다:
#
# 1. **데이터 전처리 (Data Preprocessing)**
#    - 여러 데이터 소스를 하나로 병합
#    - 컬럼명 통일, 결측값 처리
#    - Pandas 데이터 조작
#
# 2. **지표 계산 (Metric Calculation)**
#    - 복잡한 수식을 단계별로 구현
#    - 정규화, 가중 평균, Z-score 표준화
#
# 3. **탐색적 데이터 분석 (EDA)**
#    - 데이터 분포 시각화
#    - 직업군별 비교 분석
#    - 인사이트 도출
#
# ### 분석 질문
#
# 우리는 다음 질문들에 답할 것입니다:
#
# - ❓ **어떤 직업이 AI 노출도가 가장 높은가?**
# - ❓ **어떤 직업이 AI 노출도가 가장 낮은가?**
# - ❓ **직업군별로 AI 노출도에 차이가 있는가?**
# - ❓ **화이트칼라 vs 블루칼라 직업의 차이는?**
# - ❓ **AIOE 점수의 분포는 어떤 형태인가?**

# %% [markdown]
# ---
#
# ## 중요한 참고 사항
#
# ### 📌 이 분석의 의미
#
# **AIOE는 다음을 의미합니다:**
# - ✅ AI가 해당 직업의 업무를 **보완하거나 대체할 가능성**
# - ✅ 해당 직업이 AI 기술의 영향을 받는 **정도**
#
# **AIOE는 다음을 의미하지 않습니다:**
# - ❌ 해당 직업이 **완전히 사라진다**는 의미 아님
# - ❌ 높은 AIOE = 나쁨, 낮은 AIOE = 좋음 (가치 판단 아님)
# - ❌ 미래 예측 (현재 기술 수준 기준)
#
# ### 📌 분석의 한계
#
# 1. **2024년 기준 분석**
#    - AI 기술은 빠르게 발전 중
#    - 현재 못하는 것을 미래에는 할 수도 있음
#
# 2. **능력 중심 분석**
#    - 실제 직업은 능력 외에도 많은 요소가 중요
#    - 대인관계, 창의성, 책임감 등 정량화 어려운 요소 존재
#
# 3. **Language Modeling만 고려**
#    - 로봇, 자율주행 등 다른 AI 기술은 미포함
#    - 언어 중심 업무에 초점

# %% [markdown]
# ---
#
# ## 사용하는 데이터
#
# ### 1. O*NET 데이터
#
# **출처:** [O*NET OnLine](https://www.onetcenter.org/)
#
# **버전:** 30.0 (2024년 7월 공개)
#
# **내용:**
# - **894개 직업** × **52개 능력**
# - 각 능력의 **중요도(Importance)**: 1-5 척도
# - 각 능력의 **수준(Level)**: 0-7 척도
#
# **예시: Software Developers**
# - Written Comprehension: Importance=3.75, Level=4.38
# - Oral Expression: Importance=3.75, Level=4.12
# - Static Strength: Importance=1.00, Level=0.00 (거의 필요 없음)
#
# ### 2. MTurk AI 매핑 데이터
#
# **출처:** 논문 저자들이 수집한 크라우드소싱 데이터
#
# **내용:**
# - **10개 AI 응용 프로그램** × **52개 능력**
# - 각 AI가 능력을 얼마나 잘 수행하는지 **Beta 값** (0-1)
#
# **10개 AI 응용 프로그램:**
# 1. Image Recognition (이미지 인식)
# 2. Image Generation (이미지 생성)
# 3. Reading Comprehension (독해)
# 4. **Language Modeling** (언어 모델) ← **우리가 사용**
# 5. Translation (번역)
# 6. Speech Recognition (음성 인식)
# 7. ... 등
#
# **왜 Language Modeling만 사용하나요?**
# - ChatGPT, Claude, Gemini 등 최근 가장 주목받는 AI가 언어 모델
# - 범용성이 높아 다양한 업무에 적용 가능
# - 논문에서도 핵심 분석에 Language Modeling 사용

# %% [markdown]
# ---
#
# ## 노트북 구조
#
# 이 프로젝트는 **4개의 Jupyter 노트북**으로 구성됩니다:
#
# ### 📘 00_AIOE_Introduction.ipynb (현재 노트북)
# - 프로젝트 소개
# - AIOE 개념 설명
# - 연구 배경
# - 데이터 소개
#
# ### 📗 01_AIOE_Data_Preprocessing.ipynb
# **목표:** 분석을 위한 데이터 준비
#
# **주요 작업:**
# 1. O*NET Abilities 데이터 로드
# 2. MTurk AI 매핑 데이터 로드
# 3. Importance와 Level 데이터 병합
# 4. 능력명 통일 (공백, 하이픈 제거)
# 5. Beta 값 추가
# 6. 결측값 확인
# 7. 최종 데이터 저장
#
# **결과물:** `preprocessed_data.csv` (46,488행 × 6컬럼)
#
# ### 📙 02_AIOE_Calculation.ipynb
# **목표:** 각 직업의 AIOE 점수 계산
#
# **주요 작업:**
# 1. Importance, Level 정규화 (0-1 범위)
# 2. Scalar 계산 (Level × Importance)
# 3. 가중 영향도 계산 (Scalar × Beta)
# 4. 직업별 집계 (52개 능력 → 1개 점수)
# 5. Z-score 표준화
# 6. 순위 계산
#
# **결과물:** `aioe_scores.csv` (894행 × 7컬럼)
#
# ### 📕 03_AIOE_EDA.ipynb
# **목표:** AIOE 점수를 시각화하고 인사이트 도출
#
# **주요 작업:**
# 1. AIOE 분포 분석 (히스토그램)
# 2. TOP 10 & BOTTOM 10 직업
# 3. 직업군별 평균 AIOE 비교
# 4. 결론 및 인사이트
#
# **핵심 발견:**
# - 이봉분포 (Bimodal Distribution)
# - 화이트칼라 vs 블루칼라 양극화
# - 직업군별 명확한 차이
#
# ### 📔 04_AIOE_Conclusion.ipynb
# **목표:** 프로젝트 마무리 및 정리
#
# **주요 내용:**
# 1. 핵심 발견 요약
# 2. 연구의 의의와 한계
# 3. 실무 적용 방안
# 4. 추가 학습 자료

# %% [markdown]
# ---
#
# ## 핵심 개념 미리보기
#
# ### 1. 정규화 (Normalization)
#
# **문제:** 서로 다른 척도를 어떻게 비교할까?
# - Importance: 1-5 척도
# - Level: 0-7 척도
#
# **해결:** 모든 값을 0-1 범위로 변환
# ```python
# normalized_importance = importance / 5.0
# normalized_level = level / 7.0
# ```
#
# ### 2. Scalar (능력 가중치)
#
# **의미:** 각 능력이 직업에서 얼마나 중요한가?
#
# ```python
# scalar = normalized_level × normalized_importance
# ```
#
# **예시:**
# - Written Comprehension: 0.75 × 0.626 = 0.469 (매우 중요)
# - Manual Dexterity: 0.20 × 0.000 = 0.000 (안 중요)
#
# ### 3. Beta (AI 영향도)
#
# **의미:** AI가 각 능력을 얼마나 잘 수행하는가?
#
# **범위:** 0-1 (0=못함, 1=잘함)
#
# **예시:**
# - Speech Recognition: 0.953 (AI가 매우 잘함)
# - Static Strength: 0.172 (AI가 못함)
#
# ### 4. 가중 영향도
#
# **의미:** AI가 이 직업에서 실제로 얼마나 도움이 되는가?
#
# ```python
# weighted_impact = scalar × beta
# ```
#
# **핵심:**
# - 능력이 중요해도 AI가 못하면 → 영향 없음
# - AI가 잘해도 능력이 안 중요하면 → 영향 없음
# - **둘 다 높아야 큰 영향!**
#
# ### 5. Z-score 표준화
#
# **문제:** 절대값으로는 "높은지 낮은지" 판단하기 어려움
#
# **해결:** 상대적 위치로 변환
#
# ```python
# z_score = (내 점수 - 평균) / 표준편차
# ```
#
# **해석:**
# - Z = 0: 평균 (중간)
# - Z > 0: 평균보다 높음
# - Z < 0: 평균보다 낮음
# - Z > 1: 상위 16%
# - Z > 2: 상위 2.5%

# %% [markdown]
# ---
#
# ## 필요한 사전 지식
#
# ### 필수
# - ✅ Python 기초 문법
# - ✅ Pandas 기본 사용법 (DataFrame, Series)
# - ✅ 기초 통계 (평균, 표준편차)
#
# ### 권장
# - 📊 Matplotlib/Seaborn 시각화 경험
# - 🧮 정규화, 표준화 개념
# - 📈 탐색적 데이터 분석(EDA) 경험
#
# ### 걱정하지 마세요!
# - 모든 코드에 상세한 주석과 설명 포함
# - 단계별로 천천히 진행
# - 실제 데이터로 직접 실습하며 학습

# %% [markdown]
# ---
#
# ## 사용하는 라이브러리
#
# ### 데이터 처리
# ```python
# import pandas as pd           # 데이터 조작
# import numpy as np            # 수치 연산
# from scipy import stats       # 통계 함수 (zscore)
# ```
#
# ### 시각화
# ```python
# import matplotlib.pyplot as plt               # 기본 시각화
# import seaborn as sns                         # 고급 시각화
# from matplotlib import rc                     # 한글 폰트 설정
# ```
#
# ### 파일 읽기
# ```python
# pd.read_csv()     # CSV 파일
# pd.read_excel()   # Excel 파일
# ```

# %% [markdown]
# ---
#
# ## 참고 자료
#
# ### 논문
# - **Felten, E., Raj, M., & Seamans, R. (2021).** *Occupational, industry, and geographic exposure to artificial intelligence: A novel dataset and its potential uses*. Strategic Management Journal, 42(12), 2195-2217.
# - Eloundou, T., Manning, S., Mishkin, P., & Rock, D. (2023). *GPTs are GPTs: An early look at the labor market impact potential of large language models*. arXiv preprint arXiv:2303.10130.
#
# ### 데이터 출처
# - **O*NET Database**: https://www.onetcenter.org/
# - **O*NET Version 30.0**: https://www.onetcenter.org/db_releases.html
# - **AI Exposure Data**: https://aiindex.stanford.edu/
#
# ### 관련 링크
# - **SOC 코드 체계**: https://www.bls.gov/soc/
# - **O*NET OnLine**: https://www.onetonline.org/
# - **Felten AI Exposure Measure**: https://www.edwardfelten.com/
#
# ### 추가 학습
# - Pandas 공식 문서: https://pandas.pydata.org/docs/
# - Matplotlib 튜토리얼: https://matplotlib.org/stable/tutorials/index.html
# - Seaborn 갤러리: https://seaborn.pydata.org/examples/index.html
